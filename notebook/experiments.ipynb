# %%
print("Hello World")
# Out:
# Hello World

# %%
! pip install langchain
! pip install langchain-community
! pip install langchain-core

! pip install langchain-groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (0.3.25)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain) (0.3.60)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain) (0.1.147)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\program files\anaconda\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: requests<3,>=2 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\program files\anaconda\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\program files\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\program files\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\program files\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\program files\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\anaconda\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\anaconda\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\program files\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\program files\anaconda\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-community in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (0.3.22)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (0.3.60)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\program files\anaconda\lib\site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: requests<3,>=2 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\program files\anaconda\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (0.1.147)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\program files\anaconda\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\program files\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\program files\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\program files\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\program files\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\program files\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\program files\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain-community) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\program files\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\anaconda\lib\site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\anaconda\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain-community) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\program files\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\program files\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\program files\anaconda\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\program files\anaconda\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-core in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (0.3.60)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\program files\anaconda\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\program files\anaconda\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\program files\anaconda\lib\site-packages (from langchain-core) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core) (2.10.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\program files\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.126->langchain-core) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.126->langchain-core) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.126->langchain-core) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\program files\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\program files\anaconda\lib\site-packages (from pydantic>=2.7.4->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.4->langchain-core) (2.27.2)
# Requirement already satisfied: anyio in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core) (4.9.0)
# Requirement already satisfied: certifi in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core) (1.0.7)
# Requirement already satisfied: idna in c:\program files\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\anaconda\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core) (2.4.0)
# Requirement already satisfied: sniffio>=1.1 in c:\program files\anaconda\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.8-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-core<1.0.0,>=0.3.75 (from langchain-groq)
#   Downloading langchain_core-0.3.75-py3-none-any.whl.metadata (5.7 kB)
# Collecting groq<1,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.31.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from groq<1,>=0.30.0->langchain-groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\program files\anaconda\lib\site-packages (from groq<1,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from groq<1,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from groq<1,>=0.30.0->langchain-groq) (2.10.6)
# Requirement already satisfied: sniffio in c:\program files\anaconda\lib\site-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from groq<1,>=0.30.0->langchain-groq) (4.12.2)
# Collecting langsmith>=0.3.45 (from langchain-core<1.0.0,>=0.3.75->langchain-groq)
#   Downloading langsmith-0.4.27-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\program files\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\program files\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (6.0.1)
# Requirement already satisfied: packaging>=23.2 in c:\program files\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (23.2)
# Requirement already satisfied: idna>=2.8 in c:\program files\anaconda\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\program files\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.10.15)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\program files\anaconda\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\program files\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\anaconda\lib\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sp927949.ttl\appdata\roaming\python\python312\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.4.0)
# Downloading langchain_groq-0.3.8-py3-none-any.whl (16 kB)
# Downloading groq-0.31.1-py3-none-any.whl (134 kB)
#    ---------------------------------------- 0.0/134.9 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/134.9 kB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 71.7/134.9 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- 134.9/134.9 kB 997.3 kB/s eta 0:00:00
# Downloading langchain_core-0.3.75-py3-none-any.whl (443 kB)
#    ---------------------------------------- 0.0/444.0 kB ? eta -:--:--
#    ----- ---------------------------------- 61.4/444.0 kB 3.2 MB/s eta 0:00:01
#    --------- ------------------------------ 102.4/444.0 kB 1.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 184.3/444.0 kB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 235.5/444.0 kB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 286.7/444.0 kB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 389.1/444.0 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 444.0/444.0 kB 1.5 MB/s eta 0:00:00
# Downloading langsmith-0.4.27-py3-none-any.whl (384 kB)
#    ---------------------------------------- 0.0/384.8 kB ? eta -:--:--
#    ----------- ---------------------------- 112.6/384.8 kB 3.3 MB/s eta 0:00:01
#    ------------------ --------------------- 174.1/384.8 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  378.9/384.8 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 384.8/384.8 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: langsmith, groq, langchain-core, langchain-groq
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.1.147
#     Uninstalling langsmith-0.1.147:
#       Successfully uninstalled langsmith-0.1.147
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.60
#     Uninstalling langchain-core-0.3.60:
#       Successfully uninstalled langchain-core-0.3.60
# Successfully installed groq-0.31.1 langchain-core-0.3.75 langchain-groq-0.3.8 langsmith-0.4.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# guardrails-ai 0.6.6 requires typer<0.16,>=0.9.0, but you have typer 0.16.0 which is incompatible.
# langchain 0.3.25 requires langsmith<0.4,>=0.1.17, but you have langsmith 0.4.27 which is incompatible.
# langchain-community 0.3.22 requires langsmith<0.4,>=0.1.125, but you have langsmith 0.4.27 which is incompatible.

# %%
from langchain_groq import ChatGroq
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from langchain_groq import ChatGroq
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_groq\__init__.py:1
# ----> 1 from langchain_groq.chat_models import ChatGroq
#       2 from langchain_groq.version import __version__
#       4 __all__ = ["ChatGroq", "__version__"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_groq\chat_models.py:12
#       9 from typing import Any, Callable, Literal, Optional, TypedDict, Union, cast
#      11 from langchain_core._api import deprecated
# ---> 12 from langchain_core.callbacks import (
#      13     AsyncCallbackManagerForLLMRun,
#      14     CallbackManagerForLLMRun,
#      15 )
#      16 from langchain_core.language_models import LanguageModelInput
#      17 from langchain_core.language_models.chat_models import (
#      18     BaseChatModel,
#      19     LangSmithParams,
#      20     agenerate_from_stream,
#      21     generate_from_stream,
#      22 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\callbacks\__init__.py:133, in __getattr__(attr_name)
#     131 def __getattr__(attr_name: str) -> object:
#     132     module_name = _dynamic_imports.get(attr_name)
# --> 133     result = import_attr(attr_name, module_name, __spec__.parent)
#     134     globals()[attr_name] = result
#     135     return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\_import_utils.py:29, in import_attr(attr_name, module_name, package)
#      27 else:
#      28     try:
# ---> 29         module = import_module(f".{module_name}", package=package)
#      30     except ModuleNotFoundError as err:
#      31         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File c:\Program Files\Anaconda\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\callbacks\manager.py:32
#      30 from langchain_core.callbacks.stdout import StdOutCallbackHandler
#      31 from langchain_core.messages import BaseMessage, get_buffer_string
# ---> 32 from langchain_core.tracers.schemas import Run
#      33 from langchain_core.utils.env import env_var_is_set
#      35 if TYPE_CHECKING:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\tracers\schemas.py:19
#      14 from pydantic.v1 import Field as FieldV1
#      16 from langchain_core._api import deprecated
# ---> 19 @deprecated("0.1.0", alternative="Use string instead.", removal="1.0")
#      20 def RunTypeEnum() -> type[RunTypeEnumDep]:  # noqa: N802
#      21     """RunTypeEnum."""
#      22     warnings.warn(
#      23         "RunTypeEnum is deprecated. Please directly use a string instead"
#      24         " (e.g. 'llm', 'chain', 'tool').",
#      25         DeprecationWarning,
#      26         stacklevel=2,
#      27     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\_api\deprecation.py:155, in deprecate(obj, _obj_type, _name, _message, _alternative, _alternative_import, _pending, _addendum, _package)
#      84 """Decorator to mark a function, a class, or a property as deprecated.
#      85
#      86 When deprecating a classmethod, a staticmethod, or a property, the
#    (...)
#     139
#     140 """
#     141 _validate_deprecation_params(
#     142     removal, alternative, alternative_import, pending=pending
#     143 )
#     145 def deprecate(
#     146     obj: T,
#     147     *,
#     148     _obj_type: str = obj_type,
#     149     _name: str = name,
#     150     _message: str = message,
#     151     _alternative: str = alternative,
#     152     _alternative_import: str = alternative_import,
#     153     _pending: bool = pending,
#     154     _addendum: str = addendum,
# --> 155     _package: str = package,
#     156 ) -> T:
#     157     """Implementation of the decorator returned by `deprecated`."""
#     159     def emit_warning() -> None:
#
# ImportError: cannot import name 'FieldInfoV1' from 'langchain_core.utils.pydantic' (C:\Users\sp927949.ttl\AppData\Roaming\Python\Python312\site-packages\langchain_core\utils\pydantic.py)

# %%
! pip show langchain-core
! pip show langchain-groq
# Out:
# Name: langchain-core
# Version: 0.3.75
# Summary: Building applications with LLMs through composability
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\sp927949.ttl\AppData\Roaming\Python\Python312\site-packages
# Requires: jsonpatch, langsmith, packaging, pydantic, PyYAML, tenacity, typing-extensions
# Required-by: deepeval, guardrails-ai, langchain, langchain-chroma, langchain-community, langchain-groq, langchain-openai, langchain-text-splitters, ragas
# Name: langchain-groq
# Version: 0.3.8
# Summary: An integration package connecting Groq and LangChain
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\sp927949.ttl\AppData\Roaming\Python\Python312\site-packages
# Requires: groq, langchain-core
# Required-by:
